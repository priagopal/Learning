# %% [markdown]
# <a href="https://colab.research.google.com/github/priagopal/Learning/blob/master/Tumor_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9057e5a1-47ae-4c34-87fc-cf64e217c6db" name="files[]" multiple disabled />
#      <output id="result-9057e5a1-47ae-4c34-87fc-cf64e217c6db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dummyTGR.xlsx to dummyTGR.xlsx
# ...

# %%
import pandas as pd
xlsfile = pd.ExcelFile('dummyTGR.xlsx')
tum=xlsfile.parse('Dummy')
tr = tum.fillna("")

# %%
y = tr['TARGET'].values
X=tr.drop('TARGET',axis=1).values

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4c82bb98-8487-4937-a20c-3bf3a6ac0cc9" name="files[]" multiple disabled />
#      <output id="result-4c82bb98-8487-4937-a20c-3bf3a6ac0cc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tr_rs_final.xls to tr_rs_final.xls
# ...

# %%
tr.head()
# Out:
#    SUMLDIAM  SUMNLNLD  SUMDIAM  PCBSD  NADIR  ACNSD  PCNSD TARGET
# 0        15         7       22    -49     43    -21    -49     PR
# 1        78         3       81     88     22     59    268     PD
# 2        20         0       20    -53     22     -2     -9     PR
# 3        37         0       37    -14     20     17     85     PD
# 4         5         0        5    -88     20    -15    -75     PR

# %%
import pandas as pd
xlsfile = pd.ExcelFile('tr_rs_final.xls')
tum1=xlsfile.parse('Sheet1')
tr1 = tum1.fillna("")
y_test = tr1['TARGET'].values
X_test=tr1.drop('TARGET',axis=1).values

# %%
tr1.head()
# Out:
#    SUMLDIAM  SUMNLNL  SUMDIAM  PCBSD  NADIR  ACNSD  PCNSD TARGET
# 0        20       59       22    -55      8    -27    -55     PR
# 1        40       61       32    -32     12    -15    -32     PR
# 2        37        0       64     26     14     18     26     PD
# 3        19        0       89     54     20     36     54     PD
# 4        20        0      103     30     35     19     30     PD

# %%
print(y_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn= KNeighborsClassifier(n_neighbors=3)
knn.fit(X,y)
y_pred= knn.predict(X_test)
print(knn.score(X_test,y_test))
# Out:
# 0.8843283582089553

# %%
print(y_test)
print(y_pred)

# %%
y_pred  = pd.DataFrame(y_pred)
df3_out=y_pred.set_axis(['PREDICTION'],axis=1,inplace=False)
df_ = pd.merge(tr1,df3_out,how='left',left_index=True,right_index=True)
df_

df_.to_csv('tumor.csv')
