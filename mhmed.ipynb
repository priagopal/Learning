# %% [markdown]
# <a href="https://colab.research.google.com/github/priagopal/Learning/blob/master/mhmed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f8fb16ca-5ca1-4ef2-a1a8-9231d46588f3" name="files[]" multiple disabled />
#      <output id="result-f8fb16ca-5ca1-4ef2-a1a8-9231d46588f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mhmed.xlsx to mhmed.xlsx
# ...

# %%
import pandas as pd
xlsfile = pd.ExcelFile('mhmed.xlsx')
med=xlsfile.parse('Sheet1')

# %%
med.head()
